# %%
import sklearn
import pandas as pd
import polars as pl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading in data

# %%
awards = pl.read_csv('./AwardsPlayers.csv')
awards.head()
# Out:
# shape: (5, 6)
# ┌───────────┬───────────────────────────┬────────┬──────┬──────┬───────┐
# │ playerID  ┆ awardID                   ┆ yearID ┆ lgID ┆ tie  ┆ notes │
# │ ---       ┆ ---                       ┆ ---    ┆ ---  ┆ ---  ┆ ---   │
# │ str       ┆ str                       ┆ i64    ┆ str  ┆ str  ┆ str   │
# ╞═══════════╪═══════════════════════════╪════════╪══════╪══════╪═══════╡
# │ poseybu01 ┆ Lou Gehrig Memorial Award ┆ 2019   ┆ ML   ┆ null ┆ null  │
# │ klubeco01 ┆ Lou Gehrig Memorial Award ┆ 2018   ┆ ML   ┆ null ┆ null  │
# │ vottojo01 ┆ Lou Gehrig Memorial Award ┆ 2017   ┆ ML   ┆ null ┆ null  │
# │ altuvjo01 ┆ Lou Gehrig Memorial Award ┆ 2016   ┆ ML   ┆ null ┆ null  │
# │ grandcu01 ┆ Lou Gehrig Memorial Award ┆ 2015   ┆ ML   ┆ null ┆ null  │
# └───────────┴───────────────────────────┴────────┴──────┴──────┴───────┘

# %%
batting = pl.read_csv('./Batting.csv')
batting.head()
# Out:
# shape: (5, 24)
# ┌───────────┬────────┬───────┬────────┬───┬─────┬─────┬──────┬───────┐
# │ playerID  ┆ yearID ┆ stint ┆ teamID ┆ … ┆ SH  ┆ SF  ┆ GIDP ┆ G_old │
# │ ---       ┆ ---    ┆ ---   ┆ ---    ┆   ┆ --- ┆ --- ┆ ---  ┆ ---   │
# │ str       ┆ i64    ┆ i64   ┆ str    ┆   ┆ i64 ┆ i64 ┆ i64  ┆ str   │
# ╞═══════════╪════════╪═══════╪════════╪═══╪═════╪═════╪══════╪═══════╡
# │ aardsda01 ┆ 2004   ┆ 1     ┆ SFN    ┆ … ┆ 0   ┆ 0   ┆ 0    ┆ null  │
# │ aardsda01 ┆ 2006   ┆ 1     ┆ CHN    ┆ … ┆ 1   ┆ 0   ┆ 0    ┆ null  │
# │ aardsda01 ┆ 2007   ┆ 1     ┆ CHA    ┆ … ┆ 0   ┆ 0   ┆ 0    ┆ null  │
# │ aardsda01 ┆ 2008   ┆ 1     ┆ BOS    ┆ … ┆ 0   ┆ 0   ┆ 0    ┆ null  │
# │ aardsda01 ┆ 2009   ┆ 1     ┆ SEA    ┆ … ┆ 0   ┆ 0   ┆ 0    ┆ null  │
# └───────────┴────────┴───────┴────────┴───┴─────┴─────┴──────┴───────┘

# %%
pitching = pl.read_csv('./Pitching.csv')
pitching.head()
# Out:
# shape: (5, 30)
# ┌───────────┬────────┬───────┬────────┬───┬─────┬─────┬─────┬──────┐
# │ playerID  ┆ yearID ┆ stint ┆ teamID ┆ … ┆ R   ┆ SH  ┆ SF  ┆ GIDP │
# │ ---       ┆ ---    ┆ ---   ┆ ---    ┆   ┆ --- ┆ --- ┆ --- ┆ ---  │
# │ str       ┆ i64    ┆ i64   ┆ str    ┆   ┆ i64 ┆ i64 ┆ i64 ┆ i64  │
# ╞═══════════╪════════╪═══════╪════════╪═══╪═════╪═════╪═════╪══════╡
# │ aardsda01 ┆ 2004   ┆ 1     ┆ SFN    ┆ … ┆ 8   ┆ 0   ┆ 1   ┆ 1    │
# │ aardsda01 ┆ 2006   ┆ 1     ┆ CHN    ┆ … ┆ 25  ┆ 1   ┆ 3   ┆ 2    │
# │ aardsda01 ┆ 2007   ┆ 1     ┆ CHA    ┆ … ┆ 24  ┆ 2   ┆ 1   ┆ 1    │
# │ aardsda01 ┆ 2008   ┆ 1     ┆ BOS    ┆ … ┆ 32  ┆ 3   ┆ 2   ┆ 4    │
# │ aardsda01 ┆ 2009   ┆ 1     ┆ SEA    ┆ … ┆ 23  ┆ 2   ┆ 1   ┆ 2    │
# └───────────┴────────┴───────┴────────┴───┴─────┴─────┴─────┴──────┘

# %%
fielders = (pl.read_csv('./Fielding.csv')
            .select(pl.col('playerID', 'yearID', 'stint', 'teamID', 'lgID', 'POS', 'G', 'GS', 'InnOuts', 'PO', 'A', 'E', 'DP'),pl.col('PB', 'WP', 'SB', 'CS', 'ZR').cast(pl.Int32)))
fielders.head()
# Out:
# shape: (5, 18)
# ┌───────────┬────────┬───────┬────────┬───┬──────┬──────┬──────┬──────┐
# │ playerID  ┆ yearID ┆ stint ┆ teamID ┆ … ┆ WP   ┆ SB   ┆ CS   ┆ ZR   │
# │ ---       ┆ ---    ┆ ---   ┆ ---    ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ str       ┆ i64    ┆ i64   ┆ str    ┆   ┆ i32  ┆ i32  ┆ i32  ┆ i32  │
# ╞═══════════╪════════╪═══════╪════════╪═══╪══════╪══════╪══════╪══════╡
# │ aardsda01 ┆ 2004   ┆ 1     ┆ SFN    ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ aardsda01 ┆ 2006   ┆ 1     ┆ CHN    ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ aardsda01 ┆ 2007   ┆ 1     ┆ CHA    ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ aardsda01 ┆ 2008   ┆ 1     ┆ BOS    ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ aardsda01 ┆ 2009   ┆ 1     ┆ SEA    ┆ … ┆ null ┆ null ┆ null ┆ null │
# └───────────┴────────┴───────┴────────┴───┴──────┴──────┴──────┴──────┘

# %%
salaries = pl.read_csv('./Salaries.csv')
salaries.head()
# Out:
# shape: (5, 5)
# ┌────────┬────────┬──────┬───────────┬────────┐
# │ yearID ┆ teamID ┆ lgID ┆ playerID  ┆ salary │
# │ ---    ┆ ---    ┆ ---  ┆ ---       ┆ ---    │
# │ i64    ┆ str    ┆ str  ┆ str       ┆ i64    │
# ╞════════╪════════╪══════╪═══════════╪════════╡
# │ 1985   ┆ ATL    ┆ NL   ┆ barkele01 ┆ 870000 │
# │ 1985   ┆ ATL    ┆ NL   ┆ bedrost01 ┆ 550000 │
# │ 1985   ┆ ATL    ┆ NL   ┆ benedbr01 ┆ 545000 │
# │ 1985   ┆ ATL    ┆ NL   ┆ campri01  ┆ 633333 │
# │ 1985   ┆ ATL    ┆ NL   ┆ ceronri01 ┆ 625000 │
# └────────┴────────┴──────┴───────────┴────────┘

# %%
winners = (awards
 .filter(pl.col('notes') != 'null',pl.col('awardID') =='Gold Glove'))

# %% [markdown]
# # Create Gold Glove prediction dataset

# %%
Gold_Glove = (fielders
 .filter(pl.col('yearID') >= 2013)
 .group_by(pl.col('playerID','yearID','lgID','POS'))
 .agg(pl.col(['G', 'GS', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP', 'SB', 'CS', 'ZR']).sum())
 .join(winners,on = ['playerID','yearID'],how='left')
.with_columns(Gold_Glove = pl.when(pl.col('awardID') =='Gold Glove')
                                .then(pl.lit('Yes'))
                                .otherwise(pl.lit('No')))
 .with_columns(Training_Validation = pl.when(pl.col('yearID') >= 2023)
                                .then(pl.lit('Validation'))
                                .otherwise(pl.lit('Training')))
.sort(pl.col('playerID','yearID'))
)
Gold_Glove.head()
# Out:
# shape: (5, 22)
# ┌───────────┬────────┬──────┬─────┬───┬──────┬───────┬────────────┬─────────────────────┐
# │ playerID  ┆ yearID ┆ lgID ┆ POS ┆ … ┆ tie  ┆ notes ┆ Gold_Glove ┆ Training_Validation │
# │ ---       ┆ ---    ┆ ---  ┆ --- ┆   ┆ ---  ┆ ---   ┆ ---        ┆ ---                 │
# │ str       ┆ i64    ┆ str  ┆ str ┆   ┆ str  ┆ str   ┆ str        ┆ str                 │
# ╞═══════════╪════════╪══════╪═════╪═══╪══════╪═══════╪════════════╪═════════════════════╡
# │ aardsda01 ┆ 2013   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Training            │
# │ aardsda01 ┆ 2015   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Training            │
# │ abadfe01  ┆ 2013   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Training            │
# │ abadfe01  ┆ 2014   ┆ AL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Training            │
# │ abadfe01  ┆ 2015   ┆ AL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Training            │
# └───────────┴────────┴──────┴─────┴───┴──────┴───────┴────────────┴─────────────────────┘

# %%
(Gold_Glove
.filter(pl.col('yearID') == 2023))
# Out:
# shape: (2_069, 22)
# ┌───────────┬────────┬──────┬─────┬───┬──────┬───────┬────────────┬─────────────────────┐
# │ playerID  ┆ yearID ┆ lgID ┆ POS ┆ … ┆ tie  ┆ notes ┆ Gold_Glove ┆ Training_Validation │
# │ ---       ┆ ---    ┆ ---  ┆ --- ┆   ┆ ---  ┆ ---   ┆ ---        ┆ ---                 │
# │ str       ┆ i64    ┆ str  ┆ str ┆   ┆ str  ┆ str   ┆ str        ┆ str                 │
# ╞═══════════╪════════╪══════╪═════╪═══╪══════╪═══════╪════════════╪═════════════════════╡
# │ abadfe01  ┆ 2023   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ abbotan01 ┆ 2023   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ abbotco01 ┆ 2023   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ abramcj01 ┆ 2023   ┆ NL   ┆ SS  ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ abreual01 ┆ 2023   ┆ AL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ …         ┆ …      ┆ …    ┆ …   ┆ … ┆ …    ┆ …     ┆ …          ┆ …                   │
# │ zavalse01 ┆ 2023   ┆ AL   ┆ C   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ zerpaan01 ┆ 2023   ┆ AL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ zimmebr02 ┆ 2023   ┆ AL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ zuniggu01 ┆ 2023   ┆ NL   ┆ P   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# │ zuninmi01 ┆ 2023   ┆ AL   ┆ C   ┆ … ┆ null ┆ null  ┆ No         ┆ Validation          │
# └───────────┴────────┴──────┴─────┴───┴──────┴───────┴────────────┴─────────────────────┘

# %% [markdown]
# # Salary prediction data table

# %%
batting_agg = (batting
              .group_by(pl.col('playerID','yearID'))
              .agg(pl.col(['G', 'G_batting', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP']).sum()))
pitching_agg = (pitching
               .group_by(pl.col('playerID','yearID'))
               .agg(pl.col(['W', 'L', 'G', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP']).sum()))
fielding_agg = (fielders
               .group_by(pl.col(['playerID','yearID']))
               .agg(pl.col(['GS', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP', 'SB', 'CS', 'ZR']).sum()))


Combined_data = (batting_agg
                .join(pitching_agg,on = ['playerID','yearID'],how='full',suffix = "_pitching")
                .drop('playerID_pitching','yearID_pitching')
                .join(fielding_agg,on = ['playerID','yearID'],how='full',suffix = "_fielding")
                .drop('playerID_fielding','yearID_fielding'))



Salary_predict = (salaries
 .filter(pl.col('yearID') >= 2006)
 .join(Combined_data,on = ['playerID','yearID'],how='left')
 .with_columns(Training_Validation = pl.when(pl.col('yearID') == 2016)
                                .then(pl.lit('Validation'))
                                .otherwise(pl.lit('Training')))
 .sort(pl.col('playerID','yearID'))
)
Salary_predict
# Out:
# shape: (9_134, 60)
# ┌────────┬────────┬──────┬───────────┬───┬─────────────┬─────────────┬──────┬─────────────────────┐
# │ yearID ┆ teamID ┆ lgID ┆ playerID  ┆ … ┆ SB_fielding ┆ CS_fielding ┆ ZR   ┆ Training_Validation │
# │ ---    ┆ ---    ┆ ---  ┆ ---       ┆   ┆ ---         ┆ ---         ┆ ---  ┆ ---                 │
# │ i64    ┆ str    ┆ str  ┆ str       ┆   ┆ i32         ┆ i32         ┆ i32  ┆ str                 │
# ╞════════╪════════╪══════╪═══════════╪═══╪═════════════╪═════════════╪══════╪═════════════════════╡
# │ 2007   ┆ CHA    ┆ AL   ┆ aardsda01 ┆ … ┆ 0           ┆ 0           ┆ 0    ┆ Training            │
# │ 2008   ┆ BOS    ┆ AL   ┆ aardsda01 ┆ … ┆ 0           ┆ 0           ┆ 0    ┆ Training            │
# │ 2009   ┆ SEA    ┆ AL   ┆ aardsda01 ┆ … ┆ 0           ┆ 0           ┆ 0    ┆ Training            │
# │ 2010   ┆ SEA    ┆ AL   ┆ aardsda01 ┆ … ┆ 0           ┆ 0           ┆ 0    ┆ Training            │
# │ 2011   ┆ SEA    ┆ AL   ┆ aardsda01 ┆ … ┆ null        ┆ null        ┆ null ┆ Training            │
# │ …      ┆ …      ┆ …    ┆ …         ┆ … ┆ …           ┆ …           ┆ …    ┆ …                   │
# │ 2010   ┆ DET    ┆ AL   ┆ zumayjo01 ┆ … ┆ 0           ┆ 0           ┆ 0    ┆ Training            │
# │ 2011   ┆ DET    ┆ AL   ┆ zumayjo01 ┆ … ┆ null        ┆ null        ┆ null ┆ Training            │
# │ 2014   ┆ SEA    ┆ AL   ┆ zuninmi01 ┆ … ┆ 71          ┆ 28          ┆ 0    ┆ Training            │
# │ 2015   ┆ SEA    ┆ AL   ┆ zuninmi01 ┆ … ┆ 42          ┆ 22          ┆ 0    ┆ Training            │
# │ 2016   ┆ SEA    ┆ AL   ┆ zychto01  ┆ … ┆ 0           ┆ 0           ┆ 0    ┆ Validation          │
# └────────┴────────┴──────┴───────────┴───┴─────────────┴─────────────┴──────┴─────────────────────┘

# %%
(Salary_predict
.filter(pl.col('yearID') == 2016))
# Out:
# shape: (853, 60)
# ┌────────┬────────┬──────┬───────────┬───┬─────────────┬─────────────┬─────┬─────────────────────┐
# │ yearID ┆ teamID ┆ lgID ┆ playerID  ┆ … ┆ SB_fielding ┆ CS_fielding ┆ ZR  ┆ Training_Validation │
# │ ---    ┆ ---    ┆ ---  ┆ ---       ┆   ┆ ---         ┆ ---         ┆ --- ┆ ---                 │
# │ i64    ┆ str    ┆ str  ┆ str       ┆   ┆ i32         ┆ i32         ┆ i32 ┆ str                 │
# ╞════════╪════════╪══════╪═══════════╪═══╪═════════════╪═════════════╪═════╪═════════════════════╡
# │ 2016   ┆ MIN    ┆ AL   ┆ abadfe01  ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ CHA    ┆ AL   ┆ abreujo02 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ NYA    ┆ AL   ┆ ackledu01 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ COL    ┆ NL   ┆ adamecr01 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ SLN    ┆ NL   ┆ adamsma01 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ …      ┆ …      ┆ …    ┆ …         ┆ … ┆ …           ┆ …           ┆ …   ┆ …                   │
# │ 2016   ┆ ARI    ┆ NL   ┆ zieglbr01 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ DET    ┆ AL   ┆ zimmejo02 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ WAS    ┆ NL   ┆ zimmery01 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ CHN    ┆ NL   ┆ zobribe01 ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# │ 2016   ┆ SEA    ┆ AL   ┆ zychto01  ┆ … ┆ 0           ┆ 0           ┆ 0   ┆ Validation          │
# └────────┴────────┴──────┴───────────┴───┴─────────────┴─────────────┴─────┴─────────────────────┘

# %% [markdown]
# # Grid search

# %%
from sklearn.metrics import confusion_matrix

def get_metrics(y_true, y_pred, labels=None):
    """ Compute various measures from a confusion matrix

    Args:
        y_true: a column of the true labels.
        y_pred: a column of the predicted labels.
    Returns:
        A dictionary of metrics.
    """
    conf_mat = confusion_matrix(y_true, y_pred, labels=labels)
    tn, fp, fn, tp = conf_mat.ravel()

    return {'accuracy'          :  (tp + tn)/(tp + tn + fp + fn),
            'balanced_accuracy' :  0.5*tn / (tn+fp) + 0.5*tp / (tp+fn),
            'specificity'       :  tn / (tn+fp),
            'sensitivity'       :  tp / (tp+fn),
             'ppv'              :  tp / (tp + fp),
             'npv'              :  tn / (tn + fn)}

# %%
print(Salary_predict.columns)
# Out:
# ['yearID', 'teamID', 'lgID', 'playerID', 'salary', 'G', 'G_batting', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'W', 'L', 'G_pitching', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H_pitching', 'ER', 'HR_pitching', 'BB_pitching', 'SO_pitching', 'BAOpp', 'ERA', 'IBB_pitching', 'WP', 'HBP_pitching', 'BK', 'BFP', 'GF', 'R_pitching', 'SH_pitching', 'SF_pitching', 'GIDP_pitching', 'GS_fielding', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP_fielding', 'SB_fielding', 'CS_fielding', 'ZR', 'Training_Validation']

# %%
X_train = (Gold_Glove
           .filter(pl.col('Training_Validation') == 'Training')
          .select([ 'G', 'GS', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP', 'SB', 'CS', 'ZR']))
X_test =(Gold_Glove
           .filter(pl.col('Training_Validation') == 'Validation')
          .select([ 'G', 'GS', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP', 'SB', 'CS', 'ZR']))
Y_train = (Gold_Glove
           .filter(pl.col('Training_Validation') == 'Training')
          .select(['Gold_Glove']))
Y_test =(Gold_Glove
           .filter(pl.col('Training_Validation') == 'Validation')
          .select(['Gold_Glove']))

# %%
from sklearn.model_selection import StratifiedKFold

# A random state - I use random.org
state = 12

cv_obj = StratifiedKFold(n_splits=10, shuffle=True, random_state=state)
cv_obj
# Out:
# StratifiedKFold(n_splits=10, random_state=12, shuffle=True)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
param_grid_tree = {
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
}

grid_search_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, verbose=3, cv=cv_obj)
grid_search_tree.fit(X_train, Y_train)

best_tree_model = grid_search_tree.best_estimator_
y_pred_tree = best_tree_model.predict(X_valid)
tree_accuracy = accuracy_score(y_valid, y_pred_tree)

print(f'Best Decision Tree Parameters: {grid_search_tree.best_params_}')
print(f'Decision Tree Accuracy on Validation: {tree_accuracy}')
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# ...
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 8
#       1 param_grid_tree = {
#       2     'max_depth': [5, 10, 15, 20, None],
#       3     'min_samples_split': [2, 5, 10, 20],
#       4     'min_samples_leaf': [1, 2, 5, 10],
#       5 }
#       7 grid_search_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, verbose=3, cv=cv_obj)
# ----> 8 grid_search_tree.fit(X_train, Y_train)
#      10 best_tree_model = grid_search_tree.best_estimator_
#      11 y_pred_tree = best_tree_model.predict(X_valid)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:947, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     940 elif len(out) != n_candidates * n_splits:
#     941     raise ValueError(
#     942         "cv.split and cv.get_n_splits returned "
#     943         "inconsistent results. Expected {} "
#     944         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     945     )
# --> 947 _warn_or_raise_about_fit_failures(out, self.error_score)
#     949 # For callable self.scoring, the return type is only know after
#     950 # calling. If the return type is a dictionary, the error scores
#     951 # can now be inserted with the correct key. The type checking
#     952 # of out will be done in `_insert_error_scores`.
#     953 if callable(self.scoring):
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:536, in _warn_or_raise_about_fit_failures(results, error_score)
#     529 if num_failed_fits == num_fits:
#     530     all_fits_failed_message = (
#     531         f"\nAll the {num_fits} fits failed.\n"
#     532         "It is very likely that your model is misconfigured.\n"
#     533         "You can try to debug the error by setting error_score='raise'.\n\n"
#     534         f"Below are more details about the failures:\n{fit_errors_summary}"
#     535     )
# --> 536     raise ValueError(all_fits_failed_message)
#     538 else:
#     539     some_fits_failed_message = (
#     540         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     541         "The score on these train-test partitions for these parameters"
#    (...)
#     545         f"Below are more details about the failures:\n{fit_errors_summary}"
#     546     )
#
# ValueError:
# All the 1800 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/tree/_classes.py", line 1009, in fit
#     super()._fit(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/tree/_classes.py", line 252, in _fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 645, in _validate_data
#     X = check_array(X, input_name="X", **check_X_params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 997, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_array_api.py", line 521, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/polars/dataframe/frame.py", line 941, in __array__
#     arr = arr.__array__(dtype)
#           ^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'BOS'
#
# --------------------------------------------------------------------------------
# 1620 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/tree/_classes.py", line 1009, in fit
#     super()._fit(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/tree/_classes.py", line 252, in _fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 645, in _validate_data
#     X = check_array(X, input_name="X", **check_X_params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 997, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_array_api.py", line 521, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/polars/dataframe/frame.py", line 941, in __array__
#     arr = arr.__array__(dtype)
#           ^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'CHA'

# %%
print(f'Best Decision Tree Parameters: {grid_search_tree.best_params_}')
print(f'Decision Tree Accuracy on Validation: {tree_accuracy}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f'Best Decision Tree Parameters: {grid_search_tree.best_params_}')
#       2 print(f'Decision Tree Accuracy on Validation: {tree_accuracy}')
#
# NameError: name 'grid_search_tree' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid_rf = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 5, 10],
}

rf_grid_search = GridSearchCV(RandomForestClassifier(), param_grid_rf, verbose=3, cv=cv_obj)
rf_grid_search.fit(X_train, Y_train)

best_rf_model = rf_grid_search.best_estimator_
# Out:
# Fitting 10 folds for each of 240 candidates, totalling 2400 fits
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=1, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=5, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# ...
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=nan total time=   0.0s
# [CV 1/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 6/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 7/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 8/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 9/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# [CV 10/10] END max_depth=None, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 12
#       4 param_grid_rf = {
#       5     'n_estimators': [50, 100, 150, 200],
#       6     'max_depth': [5, 10, 15, 20, None],
#       7     'min_samples_split': [2, 5, 10, 20],
#       8     'min_samples_leaf': [1, 5, 10],
#       9 }
#      11 rf_grid_search = GridSearchCV(RandomForestClassifier(), param_grid_rf, verbose=3, cv=cv_obj)
# ---> 12 rf_grid_search.fit(X_train, Y_train)
#      14 best_rf_model = rf_grid_search.best_estimator_
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:947, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     940 elif len(out) != n_candidates * n_splits:
#     941     raise ValueError(
#     942         "cv.split and cv.get_n_splits returned "
#     943         "inconsistent results. Expected {} "
#     944         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     945     )
# --> 947 _warn_or_raise_about_fit_failures(out, self.error_score)
#     949 # For callable self.scoring, the return type is only know after
#     950 # calling. If the return type is a dictionary, the error scores
#     951 # can now be inserted with the correct key. The type checking
#     952 # of out will be done in `_insert_error_scores`.
#     953 if callable(self.scoring):
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:536, in _warn_or_raise_about_fit_failures(results, error_score)
#     529 if num_failed_fits == num_fits:
#     530     all_fits_failed_message = (
#     531         f"\nAll the {num_fits} fits failed.\n"
#     532         "It is very likely that your model is misconfigured.\n"
#     533         "You can try to debug the error by setting error_score='raise'.\n\n"
#     534         f"Below are more details about the failures:\n{fit_errors_summary}"
#     535     )
# --> 536     raise ValueError(all_fits_failed_message)
#     538 else:
#     539     some_fits_failed_message = (
#     540         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     541         "The score on these train-test partitions for these parameters"
#    (...)
#     545         f"Below are more details about the failures:\n{fit_errors_summary}"
#     546     )
#
# ValueError:
# All the 2400 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1263, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 997, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_array_api.py", line 521, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/polars/dataframe/frame.py", line 941, in __array__
#     arr = arr.__array__(dtype)
#           ^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'BOS'
#
# --------------------------------------------------------------------------------
# 2160 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1263, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 997, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_array_api.py", line 521, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/polars/dataframe/frame.py", line 941, in __array__
#     arr = arr.__array__(dtype)
#           ^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'CHA'

# %%
X_train = (Salary_predict
           .filter(pl.col('Training_Validation') == 'Training')
          .select(['G', 'G_batting', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'W', 'L', 'G_pitching', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H_pitching', 'ER', 'HR_pitching', 'BB_pitching', 'SO_pitching', 'BAOpp', 'ERA', 'IBB_pitching', 'WP', 'HBP_pitching', 'BK', 'BFP', 'GF', 'R_pitching', 'SH_pitching', 'SF_pitching', 'GIDP_pitching', 'GS_fielding', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP_fielding', 'SB_fielding', 'CS_fielding', 'ZR']))
X_test =(Salary_predict
           .filter(pl.col('Training_Validation') == 'Validation')
          .select(['G', 'G_batting', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'W', 'L', 'G_pitching', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H_pitching', 'ER', 'HR_pitching', 'BB_pitching', 'SO_pitching', 'BAOpp', 'ERA', 'IBB_pitching', 'WP', 'HBP_pitching', 'BK', 'BFP', 'GF', 'R_pitching', 'SH_pitching', 'SF_pitching', 'GIDP_pitching', 'GS_fielding', 'InnOuts', 'PO', 'A', 'E', 'DP', 'PB', 'WP_fielding', 'SB_fielding', 'CS_fielding', 'ZR']))
Y_train = (Salary_predict
           .filter(pl.col('Training_Validation') == 'Training')
          .select(['salary']))
Y_test =(Salary_predict
           .filter(pl.col('Training_Validation') == 'Validation')
          .select(['salary']))

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = DecisionTreeRegressor(random_state=12)
param_grid = {
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 5, 10],
    'max_features': [None, 'sqrt', 'log2'],
}
kfold = KFold(n_splits=10, shuffle=True, random_state=12)

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=12, shuffle=True),
#              estimator=DecisionTreeRegressor(random_state=12), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15, 20, None],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 5, 10, 20]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
best_model = grid_search.best_estimator_

y_pred = best_model.predict(X_test)

mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)

grid_search.best_params_, mse, r2
# Out:
# ({'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 2},
#  29083469600801.23,
#  0.16353779641950095)

# %%
import numpy as np

print(np.sqrt(mse))
# Out:
# 5392909.196417202

# %%
best_params = grid_search.best_params_
best_score = -grid_search.best_score_
test_mse = mean_squared_error(Y_test, y_pred)
test_r2 = r2_score(Y_test, y_pred)

print("Best Parameters from Grid Search:", best_params)
print("Best Cross-Validated MSE:", best_score)
print("Test MSE:", test_mse)
print("Test R-squared:", test_r2)
# Out:
# Best Parameters from Grid Search: {'max_depth': 5, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# Best Cross-Validated MSE: 16922747601899.625
# Test MSE: 29083469600801.23
# Test R-squared: 0.16353779641950095
